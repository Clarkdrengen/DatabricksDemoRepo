# %%
# %pip install dbdemos

# %%
import dbdemos

# %%
dbdemos.install('data-ingestion', overwrite=True, path='/Users/nicholas.anders.clark@gmail.com/Drafts/data-ingestion')

# %%
dbdemos.install('streaming-sessionization')

# %%
dbdemos.install('uc-01-acl')
