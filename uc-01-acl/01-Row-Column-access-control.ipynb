-- %% [markdown]
-- # 🛡️ Row and column level access control with Databricks Unity Catalog
--
-- In this demo, you'll learn how to harness the power of Unity Catalog to secure your data at a more granular level using its *row-level* and *column-level* access control capabilities.
--
--
-- ## Row level access control
--
-- <img src="https://github.com/databricks-demos/dbdemos-resources/blob/main/images/product/uc/acls/table_uc_rls.png?raw=true" width="200" style="float: right; margin-top: 20; margin-right: 20" alt="databricks-demos"/>
--
-- Row-level security allows you to automatically hide a subset of your rows based on who is attempting to query it, without having to maintain any seperate copies of your data.
--
-- A typical use-case would be to filter out rows based on your country or Business Unit : you only see the data (financial transactions, orders, customer information...) pertaining to your region, thus preventing you from having access to the entire dataset.
--
-- 💡 While this filter can be applied at the user / principal level, it is recommended to implement access policies using groups instead.
-- <br style="clear: both"/>
--
-- <img src="https://github.com/databricks-demos/dbdemos-resources/blob/main/images/product/uc/acls/table_uc_cls.png?raw=true" width="200" style="float: right; margin-top: 20; margin-right: 20; margin-left: 20" alt="databricks-demos"/>
--
-- ## Column Level access control
--
-- Similarly, column-level access control helps you mask or anonymise the data that is in certain columns of your table, depending on the user or service principal that is trying to access it. This is typically used to mask or remove sensitive PII informations from your end users (email, SSN...).
--
-- <!-- Collect usage data (view). Remove it to disable collection. View README for more details.  -->
-- <img width="1px" src="https://ppxrzfxige.execute-api.us-west-2.amazonaws.com/v1/analytics?category=governance&org_id=7474650537677415&notebook=%2F01-Row-Column-access-control&demo_name=uc-01-acl&event=VIEW&path=%2F_dbdemos%2Fgovernance%2Fuc-01-acl%2F01-Row-Column-access-control&version=1">

-- %% [markdown]
-- ## 1. Prepare the demo

-- %% [markdown]
-- ### 1.2 This demo uses groups to showcase fine grained access control.
--
-- To see the desired results for this demo, this notebook assumes that the user
-- -  __is__ a member of groups `ANALYST_USA` and `region_admin_SPAIN`
-- -  is __not__ a member of groups `bu_admin` and `fr_analysts`
--
-- If you are not a member of these groups, add yourself (or ask an admin) via workspace admin console:
--
-- __Workspace settings / Identity and access / Groups__

-- %%
%run ./_resources/00-setup
-- Out:
-- USE CATALOG `main_build`
-- using catalog.database `main_build`.`dbdemos_uc_01_acl`
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
-- If this request is failing, you're missing some groups. Make sure you are part of ANALYST_USA and not bu_admin!
SELECT 
  assert_true(is_account_group_member('account users'),      'You must be part of account users for this demo'),
  assert_true(is_account_group_member('ANALYST_USA'),        'You must be part of ANALYST_USA for this demo'),
  assert_true(not is_account_group_member('bu_admin'),       'You must NOT be part of bu_admin for this demo');

-- Cleanup any row-filters or masks that may have been added in previous runs of the demo
ALTER TABLE customers DROP ROW FILTER;
ALTER TABLE customers ALTER COLUMN address DROP MASK;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ### 1.3 Review our 'customers' table
-- We created the table in the previous notebook (make sure you run it before this one).
--
-- The table was created without restriction, all users can access all the rows

-- %%
-- Note that all rows are visible (all countries) and the 'address' column has no masking:
SELECT id, creation_date, country, address, firstname, lastname, email, gender, age_group, canal, last_activity_date, churn 
  FROM customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>creation_date</th><th>country</th><th>address</th><th>firstname</th><th>lastname</th><th>email</th><th>gender</th><th>age_group</th><th>canal</th><th>last_activity_date</th><th>churn</th></tr></thead><tbody><tr><td>f120372e-022b-41b6-88f7-d6aec8565a6e</td><td>04-19-2013 00:00:00</td><td>SPAIN</td><td>0866 Luna Crest
-- Briggsside, AR 02197</td><td>Christopher</td><td>Davis</td><td>sbrooks@hebert.com</td><td>1.0</td><td>3.0</td><td>WEBAPP</td><td>06-04-2023 16:55:26</td><td>true</td></tr><tr><td>68eac5be-ba02-4b28-898b-f531b0e294f4</td><td>01-21-2014 00:00:00</td><td>USA</td><td>4600 Richardson Dale
-- New Wanda, NE 42581</td><td>Andrea</td><td>Pierce</td><td>ybriggs@pierce.org</td><td>1.0</td><td>2.0</td><td>MOBILE</td><td>06-06-2023 20:54:21</td><td>true</td></tr><tr><td>e4ac5e22-4112-4ade-be03-ebc9a4fcd971</td><td>08-05-2021 00:00:00</td><td>USA</td><td>286 Angela Row
-- South Rachel, AL 90762</td><td>Jane</td><td>Padilla</td><td>sellersmichael@mitchell.com</td><td>1.0</td><td>6.0</td><td>PHONE</td><td>06-02-2023 20:30:20</td><td>true</td></tr><tr><td>85b5cb37-703e-4b0b-9fd2-e26bfc28ebd6</td><td>07-22-2021 00:00:00</td><td>SPAIN</td><td>15141 Mendoza Brook
-- Port Richardhaven, NE 17171</td><td>Deanna</td><td>Brewer</td><td>wnunez@cole.com</td><td>0.0</td><td>6.0</td><td>MOBILE</td><td>06-01-2023 17:08:48</td><td>false</td></tr><tr><td>ae08a336-3126-4ef8-b8c0-2ca6b0277593</td><td>08-02-2021 00:00:00</td><td>FR</td><td>3583 Green Squares
-- Port Jameshaven, MO 58447</td><td>Carla</td><td>Harper</td><td>traceyhoward@zhang-gutierrez.org</td><td>1.0</td><td>2.0</td><td>MOBILE</td><td>06-04-2023 21:36:07</td><td>true</td></tr><tr><td>449a2bba-a29d-48dc-b623-2acd83dea4fb</td><td>07-24-2021 00:00:00</td><td>FR</td><td>16999 Michael Alley Apt. 910
-- Nguyenport, KS 99031</td><td>Joel</td><td>Young</td><td>cathy85@silva.com</td><td>1.0</td><td>6.0</td><td>WEBAPP</td><td>06-02-2023 21:02:46</td><td>true</td></tr><tr><td>db8777a9-c7d8-4cae-9bac-80f4afd269b8</td><td>08-14-2021 00:00:00</td><td>USA</td><td>123 Christian Village Suite 413
-- Port Ashleyport, VA 44207</td><td>Ian</td><td>White</td><td>marie14@patrick-deleon.com</td><td>1.0</td><td>4.0</td><td>WEBAPP</td><td>06-04-2023 16:39:48</td><td>false</td></tr><tr><td>7339fbd2-5b2b-4b9a-82c6-dc577ef0cf91</td><td>07-24-2021 00:00:00</td><td>FR</td><td>58280 Brittany Terrace Apt. 046
-- Lake Pamelatown, PA 72400</td><td>Elizabeth</td><td>Ortega</td><td>marshstacy@serrano.info</td><td>1.0</td><td>6.0</td><td>PHONE</td><td>06-08-2023 08:04:54</td><td>false</td></tr><tr><td>65ae08c1-4327-47ce-b1e7-f88b196bf015</td><td>08-06-2021 00:00:00</td><td>FR</td><td>Unit 4287 Box 8773
-- DPO AE 21291</td><td>Dana</td><td>Walsh</td><td>veronica63@cardenas.com</td><td>1.0</td><td>2.0</td><td>MOBILE</td><td>06-04-2023 13:00:52</td><td>true</td></tr><tr><td>23671c7d-06b2-4a0d-a750-8faefd8348fe</td><td>07-23-2021 00:00:00</td><td>SPAIN</td><td>57462 Duncan Land
-- Stephenston, ND 98930</td><td>James</td><td>Harris</td><td>aaronbrooks@combs.info</td><td>1.0</td><td>8.0</td><td>WEBAPP</td><td>06-07-2023 03:58:15</td><td>true</td></tr><tr><td>f6554282-3f7b-4990-8f98-99957e1ee93e</td><td>08-06-2021 00:00:00</td><td>USA</td><td>77853 Taylor Mills Suite 333
-- West Michael, OH 05212</td><td>Misty</td><td>Melton</td><td>qbrooks@hudson.com</td><td>0.0</td><td>5.0</td><td>PHONE</td><td>06-06-2023 22:22:43</td><td>true</td></tr><tr><td>7d846f7b-24de-41b8-9f64-378336ee14ad</td><td>07-20-2021 00:00:00</td><td>USA</td><td>32378 Manning Island
-- South Kathleen, UT 33425</td><td>Patricia</td><td>Kline</td><td>thomasjackson@ballard.com</td><td>1.0</td><td>2.0</td><td>PHONE</td><td>06-01-2023 02:34:36</td><td>true</td></tr><tr><td>99087622-126c-4f17-92d1-7524dc519275</td><td>08-11-2021 00:00:00</td><td>USA</td><td>29264 Karl Hill Apt. 330
-- Samuelview, NJ 06954</td><td>Matthew</td><td>Morgan</td><td>rhodeschase@mejia-phelps.info</td><td>1.0</td><td>1.0</td><td>WEBAPP</td><td>06-02-2023 09:49:01</td><td>true</td></tr><tr><td>ba73b950-36fa-4e68-92df-16ca49a564bc</td><td>07-31-2021 00:00:00</td><td>SPAIN</td><td>262 Perez Underpass
-- East Katherine, AK 79551</td><td>Cathy</td><td>Franklin</td><td>burnscorey@novak-scott.biz</td><td>1.0</td><td>4.0</td><td>MOBILE</td><td>06-04-2023 06:18:08</td><td>false</td></tr><tr><td>ef5959e0-6a60-4e2a-a935-cf0f4bd99c95</td><td>07-19-2021 00:00:00</td><td>FR</td><td>62696 Price Court Apt. 321
-- Vargasfort, NH 04859</td><td>Heather</td><td>Schwartz</td><td>garciaamber@patterson.com</td><td>1.0</td><td>4.0</td><td>PHONE</td><td>06-05-2023 10:58:54</td><td>true</td></tr><tr><td>7963f8b9-eddd-440c-8bc3-1d5bfec9f1fd</td><td>08-05-2021 00:00:00</td><td>SPAIN</td><td>78095 Rachel Center Suite 295
-- Smithside, AS 17557</td><td>Jessica</td><td>Oconnor</td><td>hchoi@burns.net</td><td>1.0</td><td>10.0</td><td>PHONE</td><td>06-08-2023 17:29:43</td><td>true</td></tr><tr><td>0d9e5d61-27f1-4091-98cc-a459d9b4a977</td><td>07-25-2021 00:00:00</td><td>FR</td><td>Unit 3324 Box 2272
-- DPO AA 31600</td><td>Lauren</td><td>Lindsey</td><td>bradleylee@weeks.com</td><td>1.0</td><td>9.0</td><td>PHONE</td><td>06-06-2023 05:17:38</td><td>false</td></tr><tr><td>1f7793d7-803d-4b42-a81d-99a5ab297ec1</td><td>07-26-2021 00:00:00</td><td>FR</td><td>020 Lisa Summit
-- Ellisonbury, RI 29406</td><td>Rebecca</td><td>Mckee</td><td>oliviaavery@ramirez.com</td><td>1.0</td><td>5.0</td><td>PHONE</td><td>06-03-2023 13:38:27</td><td>false</td></tr><tr><td>6c72c8a9-6fbf-403e-b948-ecf3aaf3a343</td><td>08-18-2021 00:00:00</td><td>USA</td><td>3278 Jessica Groves
-- Port Benjamin, VA 11952</td><td>Brooke</td><td>Larson</td><td>hartmandaniel@becker.com</td><td>0.0</td><td>2.0</td><td>MOBILE</td><td>06-01-2023 15:39:23</td><td>true</td></tr><tr><td>7ecec37f-b54c-40ef-bc38-b0c74e89b859</td><td>09-01-2021 00:00:00</td><td>USA</td><td>3583 Green Squares
-- Port Jameshaven, MO 58447</td><td>Carla</td><td>Harper</td><td>traceyhoward@zhang-gutierrez.org</td><td>1.0</td><td>0.0</td><td>MOBILE</td><td>06-04-2023 21:36:07</td><td>true</td></tr><tr><td>1109fc42-f419-45bf-979f-bf9e1c338e59</td><td>09-09-2021 00:00:00</td><td>FR</td><td>03171 Sabrina Brooks
-- Sarahberg, NE 32938</td><td>Laura</td><td>Salinas</td><td>hallbryan@campbell.com</td><td>1.0</td><td>7.0</td><td>PHONE</td><td>06-07-2023 23:54:18</td><td>false</td></tr><tr><td>1aed04f3-47dc-4402-b796-c86e75f35581</td><td>08-27-2021 00:00:00</td><td>USA</td><td>6813 Vargas Hill Suite 911
-- Port Debbieside, WA 69809</td><td>Jessica</td><td>Daniel</td><td>william01@brown.info</td><td>0.0</td><td>6.0</td><td>PHONE</td><td>06-02-2023 20:30:45</td><td>true</td></tr><tr><td>3bc06c27-7eb2-4a10-8304-223b68788769</td><td>08-30-2021 00:00:00</td><td>USA</td><td>907 Singh Turnpike
-- Loriborough, DC 59235</td><td>Kevin</td><td>Evans</td><td>gonzalesjacqueline@rasmussen.biz</td><td>1.0</td><td>4.0</td><td>WEBAPP</td><td>06-09-2023 04:37:39</td><td>true</td></tr><tr><td>3e9f1429-7b39-492f-b3ba-203a74c6ef59</td><td>09-15-2021 00:00:00</td><td>FR</td><td>552 Carolyn Drive
-- South Deborah, PW 61621</td><td>Christopher</td><td>Miller</td><td>cynthia55@taylor.net</td><td>1.0</td><td>2.0</td><td>WEBAPP</td><td>06-03-2023 19:38:08</td><td>true</td></tr><tr><td>52b756f2-2b85-4af6-b3cd-e082d2418f78</td><td>09-03-2021 00:00:00</td><td>SPAIN</td><td>7068 Bell Land
-- Jerryberg, CA 12806</td><td>Natalie</td><td>Johns</td><td>gmiles@fletcher.com</td><td>0.0</td><td>3.0</td><td>PHONE</td><td>06-08-2023 18:42:47</td><td>true</td></tr><tr><td>41fcd397-fa43-4fe3-b338-fba04b794364</td><td>08-27-2021 00:00:00</td><td>FR</td><td>2267 Gilmore Radial
-- West Betty, FM 96095</td><td>Taylor</td><td>Mcdonald</td><td>sclayton@daniels-norris.biz</td><td>1.0</td><t

-- %%
-- Confirming that we can see all countries (FR, USA, SPAIN) prior to setting up row-filters:
SELECT DISTINCT(country) FROM customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th></tr></thead><tbody><tr><td>FR</td></tr><tr><td>USA</td></tr><tr><td>SPAIN</td></tr></tbody></table></div>

-- %% [markdown]
-- ##  2. Row-level access control
--
-- <img src="https://github.com/databricks-demos/dbdemos-resources/blob/main/images/product/uc/acls/table_uc_rls.png?raw=true" width="200" style="float: right; margin-left: 20; margin-right: 20" alt="databricks-demos"/>
--
-- As mentioned earlier, row-level security allows you to automatically hide rows in your table from users, based on their identity or group assignment.
--
-- In this part of the demo, we will show you how you can enforce a policy where an analyst can only access data related to customers in their country.
--
--
-- To capture the current user and check their membership to a particular group, Databricks provides you with 2 built-in functions:
-- - `current_user()`
-- - and `is_account_group_member()` respectively.

-- %%
-- get the current user (for informational purposes)
SELECT current_user(), is_account_group_member('account users');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_user()</th><th>is_account_group_member(account users)</th></tr></thead><tbody><tr><td>quentin.ambard@databricks.com</td><td>true</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 2.1. Define the access rule
--
-- To declare an access control rule, you will need to create a SQL function that returns a **boolean**.
-- Unity Catalog will then hide the row if the function returns `False`.
--
-- Inside your SQL function, you can define different conditions and implement complex logic to create this boolean return value. (e.g :  `IF(condition)-THEN(view)-ELSE`)
--
-- Here, we will apply the following logic :
--
-- 1. if the user is a `bu_admin` group member, then they can access data from all countries. (we will use `is_account_group_member('group_name')` we saw earlier)
-- 2. if the user is not a `bu_admin` group member, we'll restrict access to only the rows pertaining to regions `US` as our default regions. All other customers will be hidden!
--
-- Note that columns within whatever table that this function will be applied on, can also be referred to inside the function's conditions. You can do so by using parameters.

-- %%
CREATE OR REPLACE FUNCTION region_filter(region_param STRING) 
RETURN 
  is_account_group_member('bu_admin') or  -- bu_admin can access all regions
  region_param like "US%";                -- non bu_admin's can only access regions containing US

-- Grant access to all users to the function for the demo by making all account users owners.  Note: Don't do this in production!
GRANT ALL PRIVILEGES ON FUNCTION region_filter TO `account users`; 

-- Let's try our filter. As expected, we can access USA but not SPAIN.
SELECT region_filter('USA'), region_filter('SPAIN')
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>main.dbdemos_uc_01_acl.region_filter(USA)</th><th>main.dbdemos_uc_01_acl.region_filter(SPAIN)</th></tr></thead><tbody><tr><td>true</td><td>false</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 2.2. Apply the access rule
--
-- With our rule function declared, all that's left to do is apply it on a table and see it in action!
-- A simple `SET ROW FILTER` followed by a call to the function is all it takes.
--
-- **Note: if this is failing, make sure you're using a Shared Cluster!**

-- %%
-- Apply access rule to customers table.
-- country will be the column sent as parameter to our SQL function (region_param)
ALTER TABLE customers SET ROW FILTER region_filter ON (country);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
SELECT id, creation_date, country, address, firstname, lastname, email, gender, age_group, canal, last_activity_date, churn 
  FROM customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>creation_date</th><th>country</th><th>address</th><th>firstname</th><th>lastname</th><th>email</th><th>gender</th><th>age_group</th><th>canal</th><th>last_activity_date</th><th>churn</th></tr></thead><tbody><tr><td>c0586d5e-66a9-43bd-bd45-d486471dc184</td><td>09-14-2022 00:00:00</td><td>USA</td><td>48358 Rich Mills
-- Jamiefurt, AR 63748</td><td>Jennifer</td><td>Cummings</td><td>kirkdavid@shepherd-russell.com</td><td>1.0</td><td>5.0</td><td>PHONE</td><td>06-01-2023 08:34:42</td><td>false</td></tr><tr><td>63bc9985-e4fe-448b-8f09-ac7664009b12</td><td>10-10-2022 00:00:00</td><td>USA</td><td>72743 James Freeway
-- North Garrettton, NC 98112</td><td>Jeffrey</td><td>Walker</td><td>desiree47@bernard.com</td><td>0.0</td><td>9.0</td><td>WEBAPP</td><td>06-01-2023 09:55:20</td><td>true</td></tr><tr><td>9e3abb7c-198a-4b81-b71d-3378b09cc00d</td><td>09-17-2022 00:00:00</td><td>USA</td><td>PSC 2232, Box 6665
-- APO AE 09769</td><td>Susan</td><td>Bernard</td><td>astafford@wilkinson.net</td><td>1.0</td><td>6.0</td><td>PHONE</td><td>06-06-2023 06:59:57</td><td>true</td></tr><tr><td>ae016967-ce91-4242-8645-eb7bdbd46805</td><td>09-13-2022 00:00:00</td><td>USA</td><td>66243 Jay Manors Suite 779
-- Lake Jennifer, SC 26494</td><td>Tina</td><td>Zavala</td><td>vmiller@kirby.com</td><td>0.0</td><td>0.0</td><td>PHONE</td><td>06-01-2023 11:13:06</td><td>true</td></tr><tr><td>757ddae0-2dbe-4509-a9c0-fb92b39c6c01</td><td>10-09-2022 00:00:00</td><td>USA</td><td>09979 Moore Ranch
-- South Michelle, IA 53563</td><td>Sara</td><td>Frost</td><td>johnsonjerry@nguyen-arnold.com</td><td>0.0</td><td>4.0</td><td>PHONE</td><td>06-02-2023 12:17:23</td><td>true</td></tr><tr><td>b688620d-4958-43c4-b677-625bd07140de</td><td>10-27-2022 00:00:00</td><td>USA</td><td>525 Waters Keys Suite 884
-- Port Charlesfort, HI 62246</td><td>Adam</td><td>Smith</td><td>imiller@miles-smith.com</td><td>1.0</td><td>5.0</td><td>WEBAPP</td><td>06-03-2023 02:45:34</td><td>true</td></tr><tr><td>dc89af81-54d5-4bf6-9063-9b3e5a08eb0b</td><td>10-20-2022 00:00:00</td><td>USA</td><td>13904 Taylor Mission
-- Smithtown, OK 10380</td><td>Melanie</td><td>Bradford</td><td>fmoore@williams.org</td><td>1.0</td><td>4.0</td><td>PHONE</td><td>06-05-2023 21:44:47</td><td>true</td></tr><tr><td>92811796-5630-4b6b-a6c5-bef1dd2af700</td><td>10-22-2022 00:00:00</td><td>USA</td><td>691 Carrie Rapid Suite 134
-- Jenniferton, MA 01272</td><td>Brittany</td><td>Garza</td><td>michael84@patterson-villegas.com</td><td>0.0</td><td>3.0</td><td>MOBILE</td><td>06-04-2023 16:28:19</td><td>true</td></tr><tr><td>216113a3-1511-483d-8e27-e0468b1f342a</td><td>10-19-2022 00:00:00</td><td>USA</td><td>45614 Park Land
-- South Todd, FL 67029</td><td>Emily</td><td>Craig</td><td>nelsondorothy@glenn.biz</td><td>0.0</td><td>1.0</td><td>PHONE</td><td>06-05-2023 21:59:35</td><td>true</td></tr><tr><td>117e4909-4896-4d7a-b76a-bba2dee94edd</td><td>10-27-2022 00:00:00</td><td>USA</td><td>68012 Tiffany Forges
-- Mitchellberg, MN 48959</td><td>Marissa</td><td>Wall</td><td>matthew96@miller.com</td><td>1.0</td><td>4.0</td><td>PHONE</td><td>06-04-2023 13:42:34</td><td>true</td></tr><tr><td>dfa93134-8a33-4b8d-8a3e-ebb4e5d1c246</td><td>10-21-2022 00:00:00</td><td>USA</td><td>8004 Lambert Loaf
-- Jasonchester, OK 36421</td><td>Jeffery</td><td>Robinson</td><td>hestes@stephens.net</td><td>1.0</td><td>6.0</td><td>WEBAPP</td><td>06-07-2023 10:12:58</td><td>false</td></tr><tr><td>432b4ae1-8ae0-4a46-91f2-e1be5c55f4ea</td><td>10-23-2022 00:00:00</td><td>USA</td><td>48404 Lam Skyway
-- Davisshire, HI 04001</td><td>Kristi</td><td>Floyd</td><td>peter00@meyer.com</td><td>1.0</td><td>10.0</td><td>PHONE</td><td>06-02-2023 15:56:47</td><td>true</td></tr><tr><td>dda4fdd0-9b12-4d3c-9840-9f31f83750e9</td><td>10-29-2022 00:00:00</td><td>USA</td><td>3501 Wright Ridge Suite 542
-- Johnsonside, MP 03305</td><td>William</td><td>Romero</td><td>rriggs@armstrong.org</td><td>1.0</td><td>3.0</td><td>WEBAPP</td><td>06-08-2023 19:56:16</td><td>true</td></tr><tr><td>13c8efe1-ffa0-4d76-b7b7-1d8eca086f17</td><td>10-19-2022 00:00:00</td><td>USA</td><td>1662 Kathleen Village
-- Anneburgh, CT 25939</td><td>Sabrina</td><td>Stark</td><td>pzuniga@lawson.com</td><td>0.0</td><td>9.0</td><td>PHONE</td><td>06-02-2023 03:02:37</td><td>true</td></tr><tr><td>cf3b6a12-100d-4cdf-b2f9-2782ce0417f9</td><td>10-27-2022 00:00:00</td><td>USA</td><td>8171 Veronica Roads
-- Mileshaven, VA 93489</td><td>Keith</td><td>Roberts</td><td>james12@barajas.org</td><td>0.0</td><td>10.0</td><td>WEBAPP</td><td>06-09-2023 08:00:29</td><td>true</td></tr><tr><td>f3a8707b-540d-469c-90e4-de3d5b60dc44</td><td>10-18-2022 00:00:00</td><td>USA</td><td>Unit 3324 Box 2272
-- DPO AA 31600</td><td>Lauren</td><td>Lindsey</td><td>bradleylee@weeks.com</td><td>1.0</td><td>2.0</td><td>PHONE</td><td>06-06-2023 05:17:38</td><td>true</td></tr><tr><td>f417e3a1-de07-4818-8cc3-cb5f23a8bc6a</td><td>10-29-2022 00:00:00</td><td>USA</td><td>Unit 4954 Box 1071
-- DPO AP 19432</td><td>Tara</td><td>Booker</td><td>dbaker@ferguson.com</td><td>1.0</td><td>6.0</td><td>PHONE</td><td>06-03-2023 19:01:28</td><td>true</td></tr><tr><td>fa687e17-e4df-4b37-a41c-882c63eb2457</td><td>11-18-2022 00:00:00</td><td>USA</td><td>063 Richards Drive Apt. 637
-- South Brenda, ID 59471</td><td>Holly</td><td>Graves</td><td>brent62@hendrix.com</td><td>1.0</td><td>1.0</td><td>PHONE</td><td>06-09-2023 15:26:32</td><td>true</td></tr><tr><td>838f5883-8fcc-4720-bde2-0a7439826d92</td><td>11-30-2022 00:00:00</td><td>USA</td><td>9766 Jarvis Crossing Apt. 658
-- West Cory, NV 17371</td><td>Travis</td><td>Henry</td><td>xcruz@martinez.com</td><td>1.0</td><td>3.0</td><td>WEBAPP</td><td>06-08-2023 07:45:44</td><td>true</td></tr><tr><td>11ad3c52-d7f6-4576-adf6-94bb83ccdced</td><td>11-12-2022 00:00:00</td><td>USA</td><td>36860 Timothy Flat
-- New James, NM 04411</td><td>Joshua</td><td>Hill</td><td>hlam@key.biz</td><td>0.0</td><td>0.0</td><td>WEBAPP</td><td>06-02-2023 11:12:55</td><td>true</td></tr><tr><td>050006fc-1717-44c1-bc8f-179f0e74a5d9</td><td>11-26-2022 00:00:00</td><td>USA</td><td>096 Strickland Bridge
-- Eileenland, OR 27559</td><td>Duane</td><td>Thomas</td><td>jenny25@jackson.biz</td><td>1.0</td><td>9.0</td><td>WEBAPP</td><td>06-08-2023 21:08:17</td><td>false</td></tr><tr><td>6a9472fa-99dc-4d44-bd1e-5796a9be5528</td><td>11-18-2022 00:00:00</td><td>USA</td><td>169 Vicki Well Apt. 644
-- Webbton, TN 13858</td><td>Edward</td><td>Hernandez</td><td>hendrixbrian@ball.com</td><td>1.0</td><td>0.0</td><td>WEBAPP</td><td>06-01-2023 15:24:52</td><td>false</td></tr><tr><td>4dd53843-4894-43de-9ebf-5a5d8b1c1265</td><td>11-15-2022 00:00:00</td><td>USA</td><td>339 Laura Roads
-- Mahoneychester, MI 91816</td><td>Michael</td><td>Kelly</td><td>youngdaniel@lambert.com</td><td>0.0</td><td>7.0</td><td>WEBAPP</td><td>06-08-2023 07:24:43</td><td>true</td></tr><tr><td>d1496f96-0af4-4057-8c2b-df124d714d09</td><td>11-20-2022 00:00:00</td><td>USA</td><td>04081 Dennis Mills Apt. 036
-- Gibsonshire, VT 59504</td><td>Nicholas</td><td>Brooks</td><td>emilylopez@holloway.biz</td><td>1.0</td><td>1.0</td><td>WEBAPP</td><td>06-01-2023 02:33:42</td><td>true</td></tr><tr><td>3ac1351d-523e-47b9-adc4-ebf150bcde3e</td><td>11-26-2022 00:00:00</td><td>USA</td><td>290 Stephanie Port Apt. 500
-- Andersonmouth, CO 03059</td><td>Norman</td><td>James</td><td>ybradley@wagner.com</td><td>1.0</td><td>7.0</td><td>WEBAPP</td><td>06-08-2023 21:40:09</td><td>true</td></tr><tr><td>c2bef4e4-2c79-4b22-a002-e34e70407b7e</td><td>11-17-2022 00:00:00</td><td>USA</td><td>6086 Schultz Underpass Suite 296
-- Lake Douglas, KY 93665</td><td>Scott</td><td>Ramos</td><td>katherine91@gonzales.com</td><td>1.0</td><td>4.0</td><td>WEBAPP</td><td>06-07-2023 15:58:30</td><td>false</td></tr><tr><

-- %%
-- We should see only USA and Canada here, unless the user is a member of bu_admin:
SELECT DISTINCT(country) FROM customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th></tr></thead><tbody><tr><td>USA</td></tr></tbody></table></div>

-- %% [markdown]
-- #### This is working as expected!
--
-- We secured our table, and dynamically filter the results to only keep rows with country=USA.
--
-- Let's drop the current filter, and demonstrate a more dynamic version.

-- %%
ALTER TABLE customers DROP ROW FILTER;
-- Confirming that we can once again see all countries:
SELECT DISTINCT(country) FROM customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th></tr></thead><tbody><tr><td>FR</td></tr><tr><td>USA</td></tr><tr><td>SPAIN</td></tr></tbody></table></div>

-- %% [markdown]
-- ### 2.3 More advanced dynamic filters.
-- Let's imagine we have a few regional user groups defined as : `ANALYST_USA`, `ANALYST_SPAIN`, etc... and we want to use these groups to *dynamically* filter on a country value.
--
-- This can easily be done by checking the group based on the region value.

-- %%
CREATE OR REPLACE FUNCTION region_filter_dynamic(country_param STRING) 
RETURN 
  is_account_group_member('bu_admin') or                           -- bu_admin can access all regions
  is_account_group_member(CONCAT('ANALYST_', country_param)); --regional admins can access only if the region (country column) matches the regional admin group suffix.
  
GRANT ALL PRIVILEGES ON FUNCTION region_filter_dynamic TO `account users`; --only for demo, don't do that in prod as everybody could change the function

-- apply the new access rule to the customers table:
ALTER TABLE customers SET ROW FILTER region_filter_dynamic ON (country);

SELECT region_filter_dynamic('USA'), region_filter_dynamic('SPAIN')
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>main.dbdemos_uc_01_acl.region_filter_dynamic(USA)</th><th>main.dbdemos_uc_01_acl.region_filter_dynamic(SPAIN)</th></tr></thead><tbody><tr><td>false</td><td>false</td></tr></tbody></table></div>

-- %%
-- Since our current user is a member of ANALYST_USA, now they see only USA from our query:
SELECT DISTINCT(country) FROM customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ## 3. Column-level access control

-- %% [markdown]
-- ### 3.1. Define the access rule (masking PII data)
--
-- <img src="https://github.com/databricks-demos/dbdemos-resources/blob/main/images/product/uc/acls/table_uc_cls.png?raw=true" width="200" style="float: right; margin-top: 20; margin-left: 20; margin-right: 20" alt="databricks-demos"/>
--
-- Declaring a rule to implement column-level access control is very similar to what we did earlier for our row-level access control rule.
--
-- In this example, we'll create a SQL function with the following `IF-THEN-ELSE` logic:
--
-- - if the current user is member of the group `bu_admin`, then return the column value as-is (here `ssn`),
-- - if not, mask it completely with a constant string (here `****`)

-- %%
-- create a SQL function for a simple column mask:
CREATE OR REPLACE FUNCTION simple_mask(column_value STRING)
RETURN 
  case when is_account_group_member('bu_admin') then column_value else  "****" END;
   
GRANT ALL PRIVILEGES ON FUNCTION simple_mask TO `account users`; --only for demo, don't do that in prod as everybody could change the function
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ### 3.2. Apply the access rule
--
-- To change things a bit, instead of applying a rule on an existing table, we'll demonstrte here how we can apply a rule upon the creation of a new table.
--
-- Note: In this demo we have only one column mask function to apply. In real life, you may want to apply different column masks on different columns within the same table.

-- %%
-- Just as we can ALTER a table with new access controls, we can also apply rules during the CREATE OR REPLACE TABLE:
CREATE OR REPLACE TABLE 
  patient_ssn (
    `name` STRING, 
    ssn STRING MASK simple_mask);


-- ALTER TABLE patient_ssn ALTER COLUMN ssn SET MASK simple_mask;


GRANT ALL PRIVILEGES ON TABLE patient_ssn TO `account users`; --only for demo, don't do that in prod as everybody could change the function
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
-- Populating our newly-created table using the INSERT INTO command to insert some rows:
INSERT INTO
  patient_ssn
values
  ("Jane Doe", "111-11-1111"),
  ("Joane Doe", "123-12-1234"),
  ("Joe Doe", "222-33-4444");
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

-- %% [markdown]
-- #### We can see in our SELECT results that SSN has been masked:

-- %%
SELECT * FROM patient_ssn;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>ssn</th></tr></thead><tbody><tr><td>Jane Doe</td><td>****</td></tr><tr><td>Joane Doe</td><td>****</td></tr><tr><td>Joe Doe</td><td>****</td></tr></tbody></table></div>

-- %% [markdown]
-- ## 3. Combine RL and CL access control
--
-- <img src="https://github.com/databricks-demos/dbdemos-resources/blob/main/images/product/uc/acls/table_uc_rlscls.png?raw=true" width="200" style="float: right; margin-top: 20; margin-left: 20; margin-right: 20" alt="databricks-demos"/>
--
-- Let's go back to our customer table on which we've already applied the row-level access control, and alter it to add another layer of security by applying the column-level access rule we've created in the previous step.
--
-- As we apply it, let's make it's target the 'address' column!

-- %%
-- applying our simple masking function to the 'address' column in the 'customers' table:
ALTER TABLE
  customers
ALTER COLUMN
  address
SET
  MASK simple_mask;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
-- confirming 'address' columns has been masked:
SELECT id, creation_date, country, address, firstname, lastname, email, gender, age_group, canal, last_activity_date, churn 
FROM customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>creation_date</th><th>country</th><th>address</th><th>firstname</th><th>lastname</th><th>email</th><th>gender</th><th>age_group</th><th>canal</th><th>last_activity_date</th><th>churn</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ## 4. Change the definition of the access control rules
-- If the business ever decides to change a rule's conditions or the way they want the data to be returned in response to these conditions, it is easy to adapt with Unity Catalog.
--
-- Since the function is the central element, all you need to do is update it and the effects will automatically be reflected on all the tables that it has been attached to.
--
-- In this example, we'll rewrite our `simple_mask` column mask function and change the way we anonymse data from the rather simplistic `****`, to using the built-in sql `MASK` function ([see documentation](https://docs.databricks.com/sql/language-manual/functions/mask.html))

-- %%
-- Updating the existing simple_mask function to provide more advanced masking options via the built-in SQL MASK function:
CREATE OR REPLACE FUNCTION simple_mask(maskable_param STRING)
   RETURN 
      IF(is_account_group_member('bu_admin'), maskable_param, MASK(maskable_param, '*', '*'));
      -- You can also create custom mask transformations, such as concat(substr(maskable_param, 0, 2), "..."))
   
 -- grant access to all user to the function for the demo  
ALTER FUNCTION simple_mask OWNER TO `account users`;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- Notice: we do not need to ALTER the table with the updated function for it to take effect.

-- %%
-- confirming the masking method has changed:
SELECT id, creation_date, country, address, firstname, lastname, email, gender, age_group, canal, last_activity_date, churn 
  FROM customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>creation_date</th><th>country</th><th>address</th><th>firstname</th><th>lastname</th><th>email</th><th>gender</th><th>age_group</th><th>canal</th><th>last_activity_date</th><th>churn</th></tr></thead><tbody></tbody></table></div>

-- %%
-- confirming the masking method has also changed for the patient_ssn table:
SELECT * FROM patient_ssn;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>ssn</th></tr></thead><tbody><tr><td>Jane Doe</td><td>nnn-nn-nnnn</td></tr><tr><td>Joane Doe</td><td>nnn-nn-nnnn</td></tr><tr><td>Joe Doe</td><td>nnn-nn-nnnn</td></tr></tbody></table></div>

-- %% [markdown]
-- ## 5. Dynamic access rules with lookup data
--
-- So we've seen how through functions, Unity Catalog give us the flexibility to overwrite the definition of an access rule but also combine multiple rules on a single table to ultimately implement complex multi-dimensional access control on our data.
--
-- Let's take a step further by adding an intermediate table describing a permission model. We'll use this table to lookup pre-defined mappings of users to their corresponsing data, on which we'll base the bahavior of our access control function.

-- %% [markdown]
-- ### 5.1. Create the mapping data
-- First, let's create a mapping table. This is just a simple example, you can implement more advanced table based on your requirements
--
-- In an organization where we have a user group for each supported language, we went ahead and mapped in this table each of these groups to their corresponding countries.
--
-- - The members of the `ANALYST_USA` are thus mapped to data for `USA` or `CANADA`,
-- - the members of the `ANALYST_SPAIN` are mapped to data for `SPAIN`, `MEXICO` or `ARGENTINA`,
-- - etc
--
-- In our case, our user belongs to `ANALYST_USA`.
--
-- Note : You can easily create and assign your user to one of these groups using the account console if you have the permissions to do so.

-- %%
-- Creating a table containing the mapping between groups and countries

CREATE TABLE IF NOT EXISTS 
  map_country_group (
    identity_group STRING,
    countries ARRAY<STRING>
);

GRANT ALL PRIVILEGES ON TABLE map_country_group TO `account users`; --only for demo, don't do that in prod as everybody could change the groups

INSERT OVERWRITE 
  map_country_group (identity_group, countries) VALUES
    ('ANALYST_FR', Array("FR", "BELGIUM","CANADA","SWITZERLAND")),
    ('ANALYST_SPAIN',  Array("SPAIN","MEXICO","ARGENTINA")),
    ('ANALYST_USA', Array("USA","CANADA"));

SELECT * FROM map_country_group;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>identity_group</th><th>countries</th></tr></thead><tbody><tr><td>ANALYST_FR</td><td>List(FR, BELGIUM, CANADA, SWITZERLAND)</td></tr><tr><td>ANALYST_SPAIN</td><td>List(SPAIN, MEXICO, ARGENTINA)</td></tr><tr><td>ANALYST_USA</td><td>List(USA, CANADA)</td></tr></tbody></table></div>

-- %%
-- Query the map_country_group table to see how current user is mapped.
-- This should return the rows for ANALYST_USA since our user is assigned to these groups:
SELECT * FROM map_country_group 
  WHERE is_account_group_member(identity_group) ;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>identity_group</th><th>countries</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ### 5.3. Define the access rule with lookup data
--
-- Let's now update our dynamic row filter function to call this new table-lookup approach.
--
-- - If the current user is in the group `bu_admin`, they will be able to see all rows
-- - If the user is in another group which has a row in the `map_country_group` table, allow access to rows for the corresponding countries
--
-- You could also do it with more advanced control such as joins etc.
--
-- Spark optimizer will execute that as an efficient JOIN between the map_country_group table and your main table. You can check the query execution in Spark SQL UI for more details.

-- %%
-- Create a SQL function for row-level filter based on mapping table lookup:

CREATE OR REPLACE FUNCTION region_filter_dynamic(region_param STRING)
  RETURN 
    is_account_group_member('bu_admin') or
    exists (  
      SELECT 1 
      FROM map_country_group 
      WHERE is_account_group_member(identity_group) AND array_contains(countries, region_param)
    );

GRANT ALL PRIVILEGES ON FUNCTION region_filter_dynamic TO `account users`;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
SELECT id, creation_date, country, address, firstname, lastname, email, gender, age_group, canal, last_activity_date, churn 
  FROM customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>creation_date</th><th>country</th><th>address</th><th>firstname</th><th>lastname</th><th>email</th><th>gender</th><th>age_group</th><th>canal</th><th>last_activity_date</th><th>churn</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- As expected, the current user can only see countries mapped to the ANALYST_USA group: ["USA", "CANADA"].
--
-- Note that the same strategy can be applied at column level! You can add more advanced filters, getting metadata from other tables containing more advanced permission model based on your requirements!

-- %% [markdown]
-- ## 6. Dissociate a rule from a table
-- This dissociation of the rule from the objects you apply it to, also allows you to stop applying it on the table of your choice at any time, all without :
-- - impacting the other tables this rule is attached to
-- - discontinuing the other rules that are also applied to your table
--
-- In this example, we'll remove the address column masking we added to the `customers` in the previous section, and see how :
-- - everything continues to work as expected on the Social Security Number in the `patient_ssn` table on which it's also applied
-- - the row filter continues to take effect on the `customers` table

-- %%
-- removing the column mask on 'address' from the 'customers' table:
ALTER TABLE customers ALTER COLUMN address DROP MASK;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- Let's go ahead and deactivate the row filter from `customers` as well!

-- %%
-- dropping the row filter:
ALTER TABLE customers DROP ROW FILTER;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- Removing the mask from the patient_ssn table:

-- %%
ALTER TABLE patient_ssn ALTER COLUMN ssn DROP MASK;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ## 7. Conclusion
--
-- <img src="https://github.com/databricks-demos/dbdemos-resources/blob/main/images/product/uc/acls/table_uc_rlscls_intro.png?raw=true" width="200" style="float: right; margin-top: 20; margin-left: 20; margin-right: 20" alt="databricks-demos"/>
--
-- In this demo, we saw how through a few simple lines of code we are able to implement powerful access controls using Unity Catalog's row-level and column-level access control capabilities. We :
-- - explained the logic,
-- - navigated the lifecycle of the different components (e.g: redefining a rule, dissociating a rule from a table),
-- - and ventured in more complex use cases (e.g: combining multiple rules, dynamic access rules using lookup data)
--
-- ... so you feel ready to take full control of managing your data security policies! 💪

-- %% [markdown]
-- ### A note on Delta Sharing...
-- As of now, Delta Sharing table does not work with SQL-function-based row-level security or column masks (i.e. the methods above).
-- To create row and column level security within a Delta Share, you'd need to use dynamic views (please see the [documentation](https://docs.databricks.com/en/data-sharing/create-share.html#add-dynamic-views-to-a-share-to-filter-rows-and-columns)).
